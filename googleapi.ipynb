# %%
from googleapiclient.discovery import build
api_key = "AIzaSyCqD99ntXQiptp3AXLkiuJYzjy5LgipSRw"
cse_id ="010827283724106596928:9bf0rgukrsx"
#"010827283724106596928:jpemgkvrgr6"

# %%
def search(search_term, api_key, cse_id,start, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    print(service)
    res = service.cse().list(q=search_term, cx=cse_id,start=start,**kwargs).execute()
    return res
product = []
price = []

result = search('iphone', api_key, cse_id,start = 0)

# %%
result
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - iphone',
#     'totalResults': '3410',
#     'searchTerms': 'iphone',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
# ...

# %%
def pchome_search(search_term, api_key, cse_id,start, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    print(service)
    res = service.cse().list(q=search_term, cx=cse_id,start=start,siteSearch = 'https://shopping.pchome.com.tw/',**kwargs).execute()
    return res
product = []
price = []

result = pchome_search('空氣清淨', api_key, cse_id,start = 0)
for i in range(len(result['items'])):
    product.append(result['items'][i]['title'])
    try :
        price.append(result['items'][i]['pagemap']['offer'][0]['price'])
    except:
        text = result['items'][i]['snippet']
        re = text.find('$') 
        price.append(result['items'][i]['snippet'][re:re+6])
        print(result['items'][i]['snippet'][re:re+6])
# Out:
# ...
# $1938.

# %%
product
# Out:
# ['CoClean隨身空氣清淨機(獨立版S1) - PChome 24h購物',
#  'SAMPO 聲寶10.5L空氣清淨除濕機AD-W720P - PChome 24h購物',
#  'LASKO 極淨峰靜電集塵臭氧負離子空氣清淨機(免耗材水洗式濾網 ...',
#  '【QHL 酷奇】個人隨身項鍊式空氣清淨機- PChome 24h購物',
#  'GPLUS 防蚊空氣清淨機FA-B001 - PChome 24h購物',
#  '3M淨呼吸個人隨身型空氣清淨機FA-C20PT(松石綠)送捲筒濾網x1 ...',
#  'CoClean隨身空氣清淨機(兒童版) - PChome 24h購物',
#  '【SHARP 夏普】IG-KC15 車用空氣清淨機空氣清淨器- PChome 24h購物',
#  'SABA 抗過敏空氣清淨機SA-HX03 - PChome 24h購物',
#  'LYL太陽能智能車載空氣清淨機汽車用負離子淨化空氣機- PChome ...']

# %%
price
# Out:
# ['787',
#  '8990',
#  '11390',
#  '950',
#  '3990',
#  '2490',
#  '1461',
#  '2899',
#  '9990',
#  '$1938.']

# %%
for i in range(0,100,10):

    result = pchome_search('iphone', api_key, cse_id,start = i)
    for i in range(len(result['items'])):
        product.append(result['items'][i]['title'])
        try :
            price.append(result['items'][i]['pagemap']['offer'][0]['price'])
        except:
            text = result['items'][i]['snippet']
            re = text.find('$') 
            price.append(result['items'][i]['snippet'][re:re+6])
            print(result['items'][i]['snippet'][re:re+6])
# Out:
# ...
# $4401.
# $612☆再
# ...
# $612☆再
#
# ...
# $ 860
# ...
#
# ...

# %%
a = []
b = []
for i in range(len(product)):
    a.append(product[i].replace('- PChome 24h購物','').replace('- PChome購物中心','').replace('- PChome 24h',''))
    b.append(price[i].replace('$',''))

# %%
a
# Out:
# ['SAMPO 聲寶10.5L空氣清淨除濕機AD-W720P ',
#  'lean隨身空氣清淨機(獨立版S1) ',
#  'LASKO 極淨峰靜電集塵臭氧負離子空氣清淨機(免耗材水洗式濾網 ...',
#  '【QHL 酷奇】個人隨身項鍊式空氣清淨機',
#  '【禾聯HERAN】小餅乾多重空氣清淨機HAP-150Z1 ',
#  'GPLUS 防蚊空氣清淨機FA-B001 ',
#  'lean隨身空氣清淨機(兒童版) ',
#  '3M淨呼吸個人隨身型空氣清淨機FA-C20PT(松石綠)送捲筒濾網x1 ...',
#  '【SHARP 夏普】IG-KC15 車用空氣清淨機空氣清淨器',
#  'SABA 抗過敏空氣清淨機SA-HX03 ',
#  'SAMPO 聲寶10.5L空氣清淨除濕機AD-W720P ',
#  'lean隨身空氣清淨機(獨立版S1) ',
#  'LASKO 極淨峰靜電集塵臭氧負離子空氣清淨機(免耗材水洗式濾網 ...',
#  '【QHL 酷奇】個人隨身項鍊式空氣清淨機',
#  '【禾聯HERAN】小餅乾多重空氣清淨機HAP-150Z1 ',
#  'GPLUS 防蚊空氣清淨機FA-B001 ',
#  'lean隨身空氣清淨機(兒童版) ',
#  '3M淨呼吸個人隨身型空氣清淨機FA-C20PT(松石綠)送捲筒濾網x1 ...',
#  '【SHARP 夏普】IG-KC15 車用空氣清淨機空氣清淨器',
#  'SABA 抗過敏空氣清淨機SA-HX03 ',
#  'SABA 抗過敏空氣清淨機SA-HX03 ',
#  'LYL太陽能智能車載空氣清淨機汽車用負離子淨化空氣機- PChome ...',
#  '集塵過濾網適用Panasonic國際牌空氣清淨機VXF35/PXF35型空氣濾 ...',
#  '3M淨呼吸寶寶專用型空氣清淨機(棉花糖粉) ',
#  'ible Airvida 兒童款隨身空氣清淨機C1-無尾熊灰',
#  '3M 淨呼吸超濾淨型空氣清淨機',
#  'BRISE M1 車用負離子空氣清淨機',
#  '3M 靜電空氣清淨濾網-淨化級(2入組) ',
#  'Future Lab N7 車用空氣清淨機空氣清淨機空氣淨化器負離子除異味煙味',
# ...

# %%
b
# Out:
# ['8990',
#  '787',
#  '11390',
#  '950',
#  '',
#  '3990',
#  '1461',
#  '2490',
#  '2899',
#  '9990',
#  '8990',
#  '787',
#  '11390',
#  '950',
#  '',
#  '3990',
#  '1461',
#  '2490',
#  '2899',
#  '9990',
#  '9990',
#  '1938.',
#  '750',
#  '6490',
#  '3980',
#  '6290',
#  '2480',
#  '399',
#  '999',
#  '1299',
#  '1290',
#  '',
#  '6160',
#  '1100',
#  '1138',
#  '1990',
#  '1980.',
#  '6990',
#  '999',
#  '36800',
#  '9990',
#  '710',
#  '1290',
#  '9900',
#  '17900',
#  '730',
#  '1280',
#  '1980',
#  '1890',
#  '',
#  '7610',
#  '8880',
#  '29870',
#  '4680',
#  '',
#  '2790',
#  '',
#  '1980.',
#  '1180',
#  '',
#  '3490',
#  '4990.',
#  '1490',
#  '1450',
#  '39880',
#  '330',
#  '9999.',
#  '999',
#  '799',
#  '\n\xa0...',
#  '12737',
#  '5980.',
#  '2999.',
#  '2380',
#  '',
#  '',
#  '3680',
#  '1299',
#  '1980',
#  '',
#  '1180',
#  '799',
#  '1198',
#  ' 2490',
#  '590',
#  '11900',
#  '2590',
#  '2623',
#  '2280',
#  '499',
#  '25800',
#  '1639',
#  '1919',
#  '9990',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(list(zip(a,b)),columns =['title', 'price',])

# %%
df.to_csv('product.csv',encoding='utf_8_sig')

# %%
df.to_csv('news_content.csv',encoding='utf8')

# %%
df.describe()
# Out:
#               title price
# count           210   210
# unique          193   133
# top     愛呀！我的媽 母后價到
# freq              3    13

# %%
def google_search(search_term, api_key, cse_id,start, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    print(service)
    res = service.cse().list(q='iphone+8',
                             cx=cse_id,orTerms='shopping',
                             start=start,
                             siteSearch = 'https://www.google.com/search?tbm=shop&hl=zh-TW&source=hp&biw=&bih=').execute()
    return res

result = shopee_search("iphone", api_key, cse_id,start = 10)
for i in range(len(result['items'])):
    print('$' in result['items'][i]['title'])
    print(result['items'][i]['title'])
    #print('\n')
    
    #orTerms
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-83a6f791acd0> in <module>
#       9
#      10 result = shopee_search("iphone", api_key, cse_id,start = 10)
# ---> 11 for i in range(len(result['items'])):
#      12     print('$' in result['items'][i]['title'])
#      13     print(result['items'][i]['title'])
#
# KeyError: 'items'

# %%
result
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'previousPage': [{'title': 'Google Custom Search - iphone+6s',
#     'totalResults': '11',
#     'searchTerms': 'iphone+6s',
#     'count': 2,
#     'language': 'lang_zh-TW',
#     'inputEncoding': 'utf8',
# ...

# %%
def momo_search(search_term, api_key, cse_id,start, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    print(service)
    res = service.cse().list(q=search_term, cx=cse_id,start=start,siteSearch = 'https://www.momoshop.com.tw/main/Main.jsp',**kwargs).execute()
    return res

result = momo_search("空氣清淨", api_key, cse_id,start = 10)
for i in range(len(result['items'])):
    print('$' in result['items'][i]['snippet'])
    print(result['items'][i]['snippet'])
    #print('\n')
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-bd93d30821fb> in <module>
#       6
#       7 result = momo_search("空氣清淨", api_key, cse_id,start = 10)
# ----> 8 for i in range(len(result['items'])):
#       9     print('$' in result['items'][i]['snippet'])
#      10     print(result['items'][i]['snippet'])
#
# KeyError: 'items'

# %%
def pchome_search(search_term, api_key, cse_id,start, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    print(service)
    res = service.cse().list(q=search_term, cx=cse_id,start=start,siteSearch = 'https://shopping.pchome.com.tw/',**kwargs).execute()
    return res



result = pchome_search('空氣清淨', api_key, cse_id,start = 0)
for i in range(len(result['items'])):
    print(result['items'][i]['title'])
    try :
        print('price : ',result['items'][i]['pagemap']['offer'][0]['price'])
    except:
        text = result['items'][i]['snippet']
        re = text.find('$') 
        print('price : ',result['items'][i]['snippet'][re:re+6])
        #print('cant get price')
    print('=============')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf37fbcb5538> in <module>
#       7
#       8
# ----> 9 result = pchome_search('空氣清淨', api_key, cse_id,start = 0)
#      10 for i in range(len(result['items'])):
#      11     print(result['items'][i]['title'])
#
# NameError: name 'api_key' is not defined

# %%
def carousell_search(search_term, api_key, cse_id,start, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    print(service)
    res = service.cse().list(q=search_term, cx=cse_id,start=start,siteSearch = 'https://tw.carousell.com/',**kwargs).execute()
    return res


result = carousell_search("iphone", api_key, cse_id,start = 0)
for i in range(len(result['items'])):
    print(result['items'][i]['title'])
    try :
        print('price : ',result['items'][i]['pagemap']['offer'][0]['price'])
    except:
        text = result['items'][i]['snippet']
        re = text.find('$') 
        print('price : ',result['items'][i]['snippet'][re:re+6])
        #print('cant get price')
    print('=============')
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-beb0a7c68ac0> in <module>
#       7
#       8 result = carousell_search("iphone", api_key, cse_id,start = 0)
# ----> 9 for i in range(len(result['items'])):
#      10     print(result['items'][i]['title'])
#      11     try :
#
# KeyError: 'items'

# %%
def Phoebe_search(search_term, api_key, cse_id,start, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    print(service)
    res = service.cse().list(q=search_term, cx=cse_id,start=start,siteSearch = 'https://feebee.com.tw/',**kwargs).execute()
    return res

result = Phoebe_search('iphone', api_key, cse_id,start = 10)
for i in range(len(result['items'])):
    print(result['items'][i]['title'])
    try :
        print('price : ',result['items'][i]['pagemap']['offer'][0]['price'])
    except:
        text = result['items'][i]['snippet']
        re = text.find('$') 
        print('price : ',result['items'][i]['snippet'][re:re+6])
        #print('cant get price')
    print('=============')
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-349e1bca44b6> in <module>
#       6
#       7 result = Phoebe_search('iphone', api_key, cse_id,start = 10)
# ----> 8 for i in range(len(result['items'])):
#       9     print(result['items'][i]['title'])
#      10     try :
#
# KeyError: 'items'

# %%
def yahoo_search(search_term, api_key, cse_id,start, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    print(service)
    res = service.cse().list(q=search_term, cx=cse_id,start=start,siteSearch = 'https://www.rakuten.com.tw/',**kwargs).execute()
    return res

result = Phoebe_search('iphone', api_key, cse_id,start = 10)
for i in range(len(result['items'])):
    print(result['items'][i]['title'])
    try :
        print('price : ',result['items'][i]['pagemap']['offer'][0]['price'])
    except:
        text = result['items'][i]['snippet']
        re = text.find('$') 
        print('price : ',result['items'][i]['snippet'][re:re+6])
        #print('cant get price')
    print('=============')
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-350bf972cb7e> in <module>
#       6
#       7 result = Phoebe_search('iphone', api_key, cse_id,start = 10)
# ----> 8 for i in range(len(result['items'])):
#       9     print(result['items'][i]['title'])
#      10     try :
#
# KeyError: 'items'
